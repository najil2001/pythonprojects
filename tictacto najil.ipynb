# %%
while True: 
    import random
    player1=input('enter the name of a player:')
    player2=input('enter the name of a player:')


    players=[player1,player2]
    c=random.choice(players)
    current_player=c


    dict1={player1:'X',player2:'O'}



    b={7:' ',8:' ',9:' ',
       4:' ',5:' ',6:' ',
       1:' ',2:' ',3:' '}

    def board(b):
        print(f'{b[7]} | {b[8]} | {b[9]}')
        print(f'{b[4]} | {b[5]} | {b[6]}')
        print(f'{b[1]} | {b[2]} | {b[3]}')

    def number1():
        global d
        while True:
            print()
            print('its your turn',current_player)
            print()
            d=input('enter the number number between 1 and 9:')
            if d=='1' or d=='2' or d=='3' or d=='4' or d=='4' or d=='5' or d=='6' or d=='7' or d=='8' or d=='9':
                d=int(d)
                if b[d]=='X' or b[d]=='O':
                    pass
                else:
                    break
            else:
                pass

    def board_enter():
        if current_player==player1:
            b[d]=dict1[player1]
        else:
            b[d]=dict1[player2]



    def current_players():
        global current_player
        if current_player==player1:
            current_player=player2
        else:
            current_player=player1









    def checking():
        global game_over
        game_over=False
        if b[7]==b[8]==b[9]=='X' or  b[7]==b[8]==b[9]=='O':
            print('won',c)
            game_over=True
        elif b[4]==b[5]==b[6]=='X' or  b[4]==b[5]==b[6]=='O':
            print('won',c)
            game_over=True
        elif b[1]==b[2]==b[3]=='X' or  b[1]==b[2]==b[3]=='O':
            print('won',c)
            game_over=True
        elif b[7]==b[4]==b[1]=='X' or  b[7]==b[4]==b[1]=='O':
            print('won',c)
            game_over=True
        elif b[8]==b[5]==b[2]=='X' or  b[8]==b[5]==b[2]=='O':
            print('won',c)
            game_over=True
        elif b[9]==b[6]==b[3]=='X' or   b[9]==b[6]==b[3]=='O':
            print('won',c)
            game_over=True
        elif b[7]==b[5]==b[3]=='X' or b[7]==b[5]==b[3]=='O':
            print('won',c)
            game_over=True
        elif b[9]==b[5]==b[1]=='X' or  b[9]==b[5]==b[1]=='O':
            print('won',player1)
            game_over=True
        elif (b[1]=='X'or b[1]=='O') and (b[2]=='X' or b[2]=='O') and (b[3]=='X' or b[3]=='O') and (b[4]=='X' or b[4]=='O') and (b[5]=='X' or b[5]=='O') and (b[6]=='X' or b[6]=='O') and (b[7]=='X'or b[7]=='O') and (b[8]=='X' or b[8]=='O') and (b[9]=='X' or b[9]=='O'):
            print('Tie')
            game_over=True
        else:
            pass 



    number1()
    board_enter()
    board(b)



    while True:
        current_players()
        number1()
        board_enter()
        board(b)
        checking()
        if game_over==True:
            print()
            print('restart')
            print()
            break
# Out:
# enter the name of a player:n
# enter the name of a player:a
#
# its your turn n
#
# enter the number number between 1 and 9:4
#   |   |
# X |   |
#   |   |
#
# its your turn a
#
# enter the number number between 1 and 9:3
#   |   |
# X |   |
#   |   | O
#
# its your turn n
#
# enter the number number between 1 and 9:i
#
# its your turn n
#
# enter the number number between 1 and 9:4
#
# its your turn n
#
# enter the number number between 1 and 9:2
#   |   |
# X |   |
#   | X | O
#
# its your turn a
#
# enter the number number between 1 and 9:9
#   |   | O
# X |   |
#   | X | O
#
# its your turn n
#
# enter the number number between 1 and 9:0
#
# its your turn n
#
# enter the number number between 1 and 9:1
#   |   | O
# X |   |
# X | X | O
#
# its your turn a
#
# enter the number number between 1 and 9:7
# O |   | O
# X |   |
# X | X | O
#
# its your turn n
#
# enter the number number between 1 and 9:5
# O |   | O
# X | X |
# X | X | O
#
# its your turn a
#
# ...
