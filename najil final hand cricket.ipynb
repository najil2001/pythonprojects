# %%
import random 
player1=input('Enter name of the player:')
comp='computer'
players=[player1,comp]
a=random.choice(players)
current_player=a
player_score=0
computer_score=0




def toss(): 
    global d
    global f
    global t
    t=['head','tail']
    d=input('Enter head or tail:')
    import random
    f=random.choice(t)
    print(f)
    
    

def choice():
    global x
    global ch
    global i
    if d==f:
        x=input('choose bat or ball :')
        if x=='bat':
            print(player1,'choose bat first')
        else:
            print(comp,'choose bat first')
    else:
        ch=['bat','ball']
        import random
        i=random.choice(ch)
        print('computer choose first ',i)
        
        
        
def computer1():
    global g
    import random
    c=[0,1,2,3,4,5,6]
    g=random.choice(c)
    print('computer score:',g)

def player():
    while True:
        global b
        b=input('Enter the number between 0 and 6:')
        if b=='0'or b=='1'or b=='2'or b=='3'or b=='4'or b=='5'or b=='6':
            b=int(b)
            print(player1,'score:',b)
            break



def playing_player():
    global player_score
    player_score=0
    while True:
        global b
        b=input('Enter the number between 0 and 6:')
        if b=='0'or b=='1'or b=='2'or b=='3'or b=='4'or b=='5'or b=='6':
            b=int(b)
            print(player1,"'s score:",b)
            computer1()
            player_score=player_score+b
            if bat == 'Second':
                if player_score > computer_score:
                    print('Computer Won')
                    break
            if b==g:
                print('OUT')
                print('The final score of',player_score-b)
                print()
                break
            else:
                print('The score is:',player_score)


        else:
            pass



def playing_comp():
    global computer_score
    computer_score=0
    while True:
        import random
        player()
        c=[0,1,2,3,4,5,6]
        g=random.choice(c)
        g=int(g)
        print('computer score:',g)
        computer_score=computer_score+g
        if bat == 'Second':
            if computer_score > player_score:
                print('Computer Won')
                break
        if g==b:
            print('OUT')
            print('The final score of',computer_score-g)
            print()
            break
        else:
            print('The score is: ',computer_score)

def first_batting():
    global bat
    bat = 'First'
    if d==f:
        if x=='bat':
            playing_player()
        else:
            playing_comp()
    else:
        i==ch
        if i=='bat':
            playing_comp()
        else:
            playing_player()


            

def second_batting():
    global bat
    bat = 'Second'
    if d==f:
        if x=='ball':
            playing_player()

        else:
            playing_comp()

    else:

        i==ch
        if i=='ball':
            playing_comp()
        else:
            playing_player()




       
   




        
        

            
   


    
toss()
choice()
first_batting()
print('second batting')
print()
second_batting()
# Out:
# Enter name of the player:najil
# Enter head or tail:tail
# tail
# choose bat or ball :bat
# najil choose bat first
# Enter the number between 0 and 6:3
# najil 's score: 3
# computer score: 1
# The score is: 3
# Enter the number between 0 and 6:2
# najil 's score: 2
# computer score: 4
# The score is: 5
# Enter the number between 0 and 6:2
# najil 's score: 2
# computer score: 4
# The score is: 7
# Enter the number between 0 and 6:2
# najil 's score: 2
# computer score: 5
# The score is: 9
# Enter the number between 0 and 6:2
# najil 's score: 2
# computer score: 0
# The score is: 11
# Enter the number between 0 and 6:2
# najil 's score: 2
# computer score: 2
# OUT
# The final score of 11
#
# second batting
#
# Enter the number between 0 and 6:3
# najil score: 3
# computer score: 0
# The score is:  0
# Enter the number between 0 and 6:4
# najil score: 4
# computer score: 2
# The score is:  2
# Enter the number between 0 and 6:3
# najil score: 3
# computer score: 0
# The score is:  2
# ...

# %%
if first_batting==player1:
            playing_comp()
    else:
        playing_player()

# %% [markdown]
# # def playing():
#     global x
#     global i
#     if x=='bat':
#         return playing_player()
#     else:
#         i=='bat'
#         playing_comp()

# %%
def player():
    global b
    b=input('Enter the number between 0 and 6:')
    if b=='0'or b=='1'or b=='2'or b=='3'or b=='4'or b=='5'or b=='6':
        b=int(b)
        print(player1,'score:',b)
        
        
player()
